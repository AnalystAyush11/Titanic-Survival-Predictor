# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read Data set.
df = pd.read_csv(r'C:\Users\shriv\Downloads\Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# information of dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#description of numerical columns.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# name of columns.
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#column wise sum of all null values.
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# mean of Age column.
round(np.mean(df['Age']),2)
# Out:
# 29.7

# %%
#mean of Fare column.
round(np.mean(df['Fare']),2)
# Out:
# 32.2

# %%
#unique values from every column.
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
#unique value count from Survived column.
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# # Plot Graphs.

# %%
#Plot bar graph of Survived column.
sns.countplot(x = 'Survived', data = df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#It gives unique value count from Sex column.
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#Plot bar graph of Sex column.
sns.countplot(x = 'Sex', data = df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# Male died more then women

# %%
#Plot bar graph of Pclass column.
sns.countplot(x = 'Pclass' , data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
#Plot bar graph of Parch column.
sns.countplot(x = 'Parch' , data=df)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %% [markdown]
# Poor people died more because Rich people paid money and succeed in escaping
# Those people who does not have any sibling or spouse died more.
# Those people who does not have any parent or child died

# %%
#Plot bar graph of Pclass and Sex column.
sns.countplot(x = 'Pclass' , hue= 'Sex', data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
#Plot bar graph of Survived and Sex column.
sns.countplot(x = 'Survived', hue = 'Sex', data = df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#Plot bar graph of Survived and Pclass column.
sns.countplot(x = 'Survived', hue = 'Pclass', data = df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# # Delete Unwanted columns from dataset.

# %%
#Delete columns that are of no use.
df.drop(['PassengerId','Name','Ticket','Cabin'], axis = 1, inplace = True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
#Rename column.
df.rename(columns = {'Sex':'Gender'}, inplace = True)

# %%
df
# Out:
#      Survived  Pclass  Gender   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df.isna().sum()
df
# Out:
#      Survived  Pclass  Gender   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
#Plot heatmap of null values.
sns.heatmap(df.isna(), cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %%
#Fill null values from Age column with median of column.
df['Age'].fillna(df['Age'].median(), inplace = True)

# %%
df
# Out:
#      Survived  Pclass  Gender   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  28.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Gender      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
#Sort values from Pclass column.
df.sort_values('Pclass')
# Out:
#      Survived  Pclass  Gender   Age  SibSp  Parch      Fare Embarked
# 445         1       1    male   4.0      0      2   81.8583        S
# 310         1       1  female  24.0      0      0   83.1583        C
# 309         1       1  female  30.0      0      0   56.9292        C
# 307         1       1  female  17.0      1      0  108.9000        C
# 306         1       1  female  28.0      0      0  110.8833        C
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 379         0       3    male  19.0      0      0    7.7750        S
# 381         1       3  female   1.0      0      2   15.7417        C
# 382         0       3    male  32.0      0      0    7.9250        S
# 371         0       3    male  18.0      1      0    6.4958        S
# 890         0       3    male  32.0      0      0    7.7500        Q
#
# [891 rows x 8 columns]

# %%
#Sort values from Age column.
df.sort_values('Age')
# Out:
#      Survived  Pclass  Gender    Age  SibSp  Parch     Fare Embarked
# 803         1       3    male   0.42      0      1   8.5167        C
# 755         1       2    male   0.67      1      1  14.5000        S
# 644         1       3  female   0.75      2      1  19.2583        C
# 469         1       3  female   0.75      2      1  19.2583        C
# 831         1       2    male   0.83      1      1  18.7500        S
# ..        ...     ...     ...    ...    ...    ...      ...      ...
# 116         0       3    male  70.50      0      0   7.7500        Q
# 96          0       1    male  71.00      0      0  34.6542        C
# 493         0       1    male  71.00      0      0  49.5042        C
# 851         0       3    male  74.00      0      0   7.7750        S
# 630         1       1    male  80.00      0      0  30.0000        S
#
# [891 rows x 8 columns]

# %%
#Plot scatter plot.
df.plot(x = 'Age', y = 'Fare', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
#Plot box plot.
df.plot(x = 'Age', y = 'Fare', kind = 'box')
# Out:
# <AxesSubplot:>

# %%
#Plot pairplot of dataset.
plt.figure(figsize = (30,30))
sns.pairplot(df,kind = 'scatter')

# %%
#Polt pairplot of data.
sns.pairplot(df,kind = 'scatter', hue = 'Gender')

# %%
#Gives correlation of data.
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.064910 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.339898  0.083081  0.018443 -0.549500
# Age      -0.064910 -0.339898  1.000000 -0.233296 -0.172482  0.096688
# SibSp    -0.035322  0.083081 -0.233296  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.172482  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096688  0.159651  0.216225  1.000000

# %%
#Plot heatmap data.
plt.figure(figsize = (10,7))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
#Plot heatmap with colors.
plt.figure(figsize = (10,7))
sns.heatmap(df.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <AxesSubplot:>
